# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name: Abdulrahman Aber, Benjamin Bai, Charles Pan, Kevin Rivera
# * Student pace: Full Time
# * Scheduled project review date/time:
# * Instructor name: David Elliott
# * Blog post URL:

# %% [markdown]
# # Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import sqlite3 as sq
conn = sq.connect('./im.db')
cur = conn.cursor()

# %% [markdown]
# # BOM Movie Gross DF
# Columns Removed: None

# %%
bom_movie_gross_df = pd.read_csv('./zippedData/bom.movie_gross.csv.gz')

bom_movie_gross_df.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
sorted_bom = bom_movie_gross_df.sort_values(by=['domestic_gross'],ascending=False).head(20)
sorted_bom
# Out:
#                                 title studio  domestic_gross foreign_gross  \
# 1872     Star Wars: The Force Awakens     BV     936700000.0       1,131.6
# 3080                    Black Panther     BV     700100000.0     646900000
# 3079           Avengers: Infinity War     BV     678800000.0       1,369.5
# 1873                   Jurassic World   Uni.     652300000.0       1,019.4
# 727             Marvel's The Avengers     BV     623400000.0     895500000
# 2758         Star Wars: The Last Jedi     BV     620200000.0     712400000
# 3082                    Incredibles 2     BV     608600000.0     634200000
# 2323     Rogue One: A Star Wars Story     BV     532200000.0     523900000
# 2759      Beauty and the Beast (2017)     BV     504000000.0     759500000
# 2324                     Finding Dory     BV     486300000.0     542300000
# 1875          Avengers: Age of Ultron     BV     459000000.0     946400000
# ...

# %%
bom_movie_gross_df.sort_values(by=['domestic_gross'],ascending=False).head(85)
# Out:
#                               title studio  domestic_gross foreign_gross  year
# 1872   Star Wars: The Force Awakens     BV     936700000.0       1,131.6  2015
# 3080                  Black Panther     BV     700100000.0     646900000  2018
# 3079         Avengers: Infinity War     BV     678800000.0       1,369.5  2018
# 1873                 Jurassic World   Uni.     652300000.0       1,019.4  2015
# 727           Marvel's The Avengers     BV     623400000.0     895500000  2012
# ...                             ...    ...             ...           ...   ...
# 2760        The Fate of the Furious   Uni.     226000000.0       1,010.0  2017
# 1487                     Big Hero 6     BV     222500000.0     435300000  2014
# 3086  Mission: Impossible - Fallout   Par.     220200000.0     571000000  2018
# 738                             Ted   Uni.     218800000.0     330600000  2012
# 9          How to Train Your Dragon   P/DW     217600000.0     277300000  2010
#
# [85 rows x 5 columns]

# %%
bom_movie_gross_df.dropna(inplace=True)

# %%
bom_movie_gross_df["domestic_gross"]=bom_movie_gross_df["domestic_gross"].astype(int)

# %%
bom_movie_gross_df
# Out:
#                                                   title        studio  \
# 0                                           Toy Story 3            BV
# 1                            Alice in Wonderland (2010)            BV
# 2           Harry Potter and the Deathly Hallows Part 1            WB
# 3                                             Inception            WB
# 4                                   Shrek Forever After          P/DW
# ...                                                 ...           ...
# 3275                                    I Still See You           LGF
# 3286                              The Catcher Was a Spy           IFC
# 3309                                         Time Freak    Grindstone
# 3342  Reign of Judges: Title of Liberty - Concept Short  Darin Southa
# 3353            Antonio Lopez 1970: Sex Fashion & Disco            FM
#
#       domestic_gross  foreign_gross  year
# 0          415000000      652000000  2010
# ...

# %%
bom_movie_gross_df['foreign_gross'].loc[1872] = 1131.00 * 1000000
# Out:
# /var/folders/xp/ksk4jb6j25df8dk_14f29cqw0000gn/T/ipykernel_2195/2796531944.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bom_movie_gross_df['foreign_gross'].loc[1872] = 1131.00 * 1000000

# %%
bom_movie_gross_df['foreign_gross'].loc[3079] = 1369.5 * 1000000
# Out:
# /var/folders/xp/ksk4jb6j25df8dk_14f29cqw0000gn/T/ipykernel_2195/1540942609.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bom_movie_gross_df['foreign_gross'].loc[3079] = 1369.5 * 1000000

# %%
bom_movie_gross_df['foreign_gross'].loc[1873] = 1019.4 * 1000000
# Out:
# /var/folders/xp/ksk4jb6j25df8dk_14f29cqw0000gn/T/ipykernel_2195/801416338.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bom_movie_gross_df['foreign_gross'].loc[1873] = 1019.4 * 1000000

# %%
bom_movie_gross_df['foreign_gross'].loc[1874] = 1163.0 * 1000000
# Out:
# /var/folders/xp/ksk4jb6j25df8dk_14f29cqw0000gn/T/ipykernel_2195/2830256213.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bom_movie_gross_df['foreign_gross'].loc[1874] = 1163.0 * 1000000

# %%
bom_movie_gross_df['foreign_gross']=bom_movie_gross_df['foreign_gross'].astype(int)

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))
x = sorted_bom['title']
y = sorted_bom['domestic_gross'] + sorted_bom['foreign_gross']

ax1.bar(x,y)
ax1.set_xlabel('Movie Names')
ax1.set_ylabel('Domestic Gross(in 1 bils)')
ax.set_title('Top 10 Domestic Grossing Movies')
plt.xticks(rotation=90);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/opt/anaconda3/envs/brother_rocks_workflow/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:163, in _na_arithmetic_op(left, right, op, is_cmp)
#     162 try:
# --> 163     result = func(left, right)
#     164 except TypeError:
#
# File ~/opt/anaconda3/envs/brother_rocks_workflow/lib/python3.10/site-packages/pandas/core/computation/expressions.py:239, in evaluate(op, a, b, use_numexpr)
#     237     if use_numexpr:
#     238         # error: "None" not callable
# --> 239         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240 return _evaluate_standard(op, op_str, a, b)
#
# File ~/opt/anaconda3/envs/brother_rocks_workflow/lib/python3.10/site-packages/pandas/core/computation/expressions.py:69, in _evaluate_standard(op, op_str, a, b)
#      68     _store_test_result(False)
# ---> 69 return op(a, b)
#
# ...

# %% [markdown]
# # IMDB DB DFS

# %%
imdb_schema = pd.read_sql('''SELECT * FROM sqlite_master''',conn)
imdb_schema
# Out:
#     type           name       tbl_name  rootpage  \
# 0  table   movie_basics   movie_basics         2
# 1  table      directors      directors         3
# 2  table      known_for      known_for         4
# 3  table     movie_akas     movie_akas         5
# 4  table  movie_ratings  movie_ratings         6
# 5  table        persons        persons         7
# 6  table     principals     principals         8
# 7  table        writers        writers         9
#
#                                                  sql
# 0  CREATE TABLE "movie_basics" (\n"movie_id" TEXT...
# 1  CREATE TABLE "directors" (\n"movie_id" TEXT,\n...
# 2  CREATE TABLE "known_for" (\n"person_id" TEXT,\...
# 3  CREATE TABLE "movie_akas" (\n"movie_id" TEXT,\...
# 4  CREATE TABLE "movie_ratings" (\n"movie_id" TEX...
# 5  CREATE TABLE "persons" (\n"person_id" TEXT,\n ...
# 6  CREATE TABLE "principals" (\n"movie_id" TEXT,\...
# 7  CREATE TABLE "writers" (\n"movie_id" TEXT,\n  ...

# %%
movie_basics_df = pd.read_sql('''select * from movie_ratings''', conn)
movie_basics_df.head()
# Out:
#      movie_id  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
directors_df = pd.read_sql("""select * from directors""",conn)
directors_df.head()
# Out:
#     movie_id  person_id
# 0  tt0285252  nm0899854
# 1  tt0462036  nm1940585
# 2  tt0835418  nm0151540
# 3  tt0835418  nm0151540
# 4  tt0878654  nm0089502

# %%
known_for_df = pd.read_sql("""select * from known_for""",conn)
known_for_df.head()
# Out:
#    person_id   movie_id
# 0  nm0061671  tt0837562
# 1  nm0061671  tt2398241
# 2  nm0061671  tt0844471
# 3  nm0061671  tt0118553
# 4  nm0061865  tt0896534

# %%
movie_akas_df = pd.read_sql("""select * from movie_akas""",conn)
movie_akas_df.head()
# Out:
#     movie_id  ordering                                    title region  \
# 0  tt0369610        10                            Джурасик свят     BG
# 1  tt0369610        11                        Jurashikku warudo     JP
# 2  tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3  tt0369610        13                  O Mundo dos Dinossauros     BR
# 4  tt0369610        14                           Jurassic World     FR
#
#   language        types   attributes  is_original_title
# 0       bg         None         None                0.0
# 1     None  imdbDisplay         None                0.0
# 2     None  imdbDisplay         None                0.0
# 3     None         None  short title                0.0
# 4     None  imdbDisplay         None                0.0

# %%
movie_ratings_df = pd.read_sql("""select * from movie_ratings""",conn)
movie_ratings_df.head()
# Out:
#      movie_id  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
persons_df = pd.read_sql("""select * from persons""",conn)
persons_df.head()
# Out:
#    person_id       primary_name  birth_year  death_year  \
# 0  nm0061671  Mary Ellen Bauder         NaN         NaN
# 1  nm0061865       Joseph Bauer         NaN         NaN
# 2  nm0062070         Bruce Baum         NaN         NaN
# 3  nm0062195       Axel Baumann         NaN         NaN
# 4  nm0062798        Pete Baxter         NaN         NaN
#
#                                  primary_profession
# 0         miscellaneous,production_manager,producer
# 1        composer,music_department,sound_department
# 2                        miscellaneous,actor,writer
# 3  camera_department,cinematographer,art_department
# 4  production_designer,art_department,set_decorator

# %%
principals_df = pd.read_sql("""select * from principals""",conn)
principals_df.head()
# Out:
#     movie_id  ordering  person_id  category       job        characters
# 0  tt0111414         1  nm0246005     actor      None       ["The Man"]
# 1  tt0111414         2  nm0398271  director      None              None
# 2  tt0111414         3  nm3739909  producer  producer              None
# 3  tt0323808        10  nm0059247    editor      None              None
# 4  tt0323808         1  nm3579312   actress      None  ["Beth Boothby"]

# %%
writers_df = pd.read_sql("""select * from writers""",conn)
writers_df.head()
# Out:
#     movie_id  person_id
# 0  tt0285252  nm0899854
# 1  tt0438973  nm0175726
# 2  tt0438973  nm1802864
# 3  tt0462036  nm1940585
# 4  tt0835418  nm0310087

# %% [markdown]
# # RT Movie Info DF
# Columns Removed: Synopsis, Currency, Box_Office (getting box office data elsewhere)
# Note - Break genres into multiple columns or somehow else clean it or just do contains

# %%
rt_movie_info_df = pd.read_csv('./zippedData/rt.movie_info.tsv.gz', sep='\t')
rt_movie_info_df.head()
# Out:
#    id                                           synopsis rating  \
# 0   1  This gritty, fast-paced, and innovative police...      R
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
# 2   5  Illeana Douglas delivers a superb performance ...      R
# 3   6  Michael Douglas runs afoul of a treacherous su...      R
# 4   7                                                NaN     NR
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Science Fiction and Fantasy  David Cronenberg
# 2    Drama|Musical and Performing Arts    Allison Anders
# 3           Drama|Mystery and Suspense    Barry Levinson
# 4                        Drama|Romance    Rodney Bennett
#
#                             writer  theater_date      dvd_date currency  \
# 0                   Ernest Tidyman   Oct 9, 1971  Sep 25, 2001      NaN
# 1     David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# ...

# %% [markdown]
# # RT Reviews DF
# Columns Removed: Review, Critic, Top_Critic
# Note - can we link this to movie names? scrape movie titles from ID?

# %%
rt_reviews_df = pd.read_csv(('./zippedData/rt.reviews.tsv.gz'), sep='\t', encoding= 'unicode_escape')
rt_reviews_df.tail()
# Out:
#          id                                             review rating   fresh  \
# 54427  2000  The real charm of this trifle is the deadpan c...    NaN   fresh
# 54428  2000                                                NaN    1/5  rotten
# 54429  2000                                                NaN    2/5  rotten
# 54430  2000                                                NaN  2.5/5  rotten
# 54431  2000                                                NaN    3/5   fresh
#
#                   critic  top_critic        publisher                date
# 54427      Laura Sinagra           1    Village Voice  September 24, 2002
# 54428  Michael Szymanski           0       Zap2it.com  September 21, 2005
# 54429       Emanuel Levy           0  EmanuelLevy.Com       July 17, 2005
# 54430   Christopher Null           0   Filmcritic.com   September 7, 2003
# 54431    Nicolas Lacroix           0     Showbizz.net   November 12, 2002

# %% [markdown]
# # TMDB Movies DF
# - Remove Columns: Unnamed: 0, TBD

# %%
tmdb_movies_df = pd.read_csv('./zippedData/tmdb.movies.csv.gz')
tmdb_movies_df.head()
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# ...

# %% [markdown]
# # TN Movie Budgets DF
# Remove Columns: None

# %%
tn_movie_budgets_df = pd.read_csv('./zippedData/tn.movie_budgets.csv.gz')
tn_movie_budgets_df
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# ...

# %%
list_of_movies = [tn_movie_budgets_df['movie']]

# %%
list_of_movies
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [31], in <cell line: 1>()
# ----> 1 list_of_movies.to_csv('list of movies.csv')
#
# AttributeError: 'list' object has no attribute 'to_csv'

# %%
tn_movie_budgets_df['production_budget'] = tn_movie_budgets_df['production_budget'].str.replace("$", "")
tn_movie_budgets_df['production_budget'] = tn_movie_budgets_df['production_budget'].str.replace(",", "")
tn_movie_budgets_df['production_budget']=tn_movie_budgets_df['production_budget'].astype(int)
# Out:
# /var/folders/xp/ksk4jb6j25df8dk_14f29cqw0000gn/T/ipykernel_9779/66100292.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   tn_movie_budgets_df['production_budget'] = tn_movie_budgets_df['production_budget'].str.replace("$", "")

# %%
tn_movie_budgets_df['worldwide_gross'] = tn_movie_budgets_df['worldwide_gross'].str.replace("$", "")
tn_movie_budgets_df['worldwide_gross'] = tn_movie_budgets_df['worldwide_gross'].str.replace(",", "")
tn_movie_budgets_df['worldwide_gross']=tn_movie_budgets_df['worldwide_gross'].astype(float)
# Out:
# /var/folders/xp/ksk4jb6j25df8dk_14f29cqw0000gn/T/ipykernel_9779/2859872329.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   tn_movie_budgets_df['worldwide_gross'] = tn_movie_budgets_df['worldwide_gross'].str.replace("$", "")

# %%
tn_movie_budgets_df['Cost_to_Revenue'] = (tn_movie_budgets_df['production_budget'] / tn_movie_budgets_df['worldwide_gross'])
tn_movie_budgets_df.head()
tn_movie_budgets_df['Cost/Worldwide_percent'] = [("{:.0%}".format(x)) for x in tn_movie_budgets_df['Cost_to_Revenue']]
formatc[1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [41], in <cell line: 4>()
#       2 tn_movie_budgets_df.head()
#       3 tn_movie_budgets_df['Cost/Worldwide_percent'] = [("{:.0%}".format(x)) for x in tn_movie_budgets_df['Cost_to_Revenue']]
# ----> 4 formatc[1]
#
# NameError: name 'formatc' is not defined

# %%
tn_movie_budgets_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [21], in <cell line: 1>()
# ----> 1 tn_movie_budgets_df
#
# NameError: name 'tn_movie_budgets_df' is not defined

# %%
sorted_tn = tn_movie_budgets_df.sort_values(by=['production_budget'],ascending=False).head(20)
sorted_tn
# Out:
#     id  release_date                                        movie  \
# 0    1  Dec 18, 2009                                       Avatar
# 1    2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2    3   Jun 7, 2019                                 Dark Phoenix
# 3    4   May 1, 2015                      Avengers: Age of Ultron
# 4    5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# 5    6  Dec 18, 2015         Star Wars Ep. VII: The Force Awakens
# 6    7  Apr 27, 2018                       Avengers: Infinity War
# 7    8  May 24, 2007   Pirates of the Caribbean: At Worldâs End
# 8    9  Nov 17, 2017                               Justice League
# 9   10   Nov 6, 2015                                      Spectre
# 10  11  Jul 20, 2012                        The Dark Knight Rises
# 11  12  May 25, 2018                      Solo: A Star Wars Story
# 12  13   Jul 2, 2013                              The Lone Ranger
# ...

# %% [markdown]
# # VISUALIZATIONS

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))
x = sorted_tn['movie']
y = sorted_tn['Cost_to_Revenue']

ax1.bar(x,y)
ax1.set_xlabel('Movie Names')
ax1.set_ylabel('Cost_to_Revenue(in %)')
ax1.set_title('Budget to WorldwideGross Ratio')
plt.xticks(rotation=90);
# Out:
# /Users/abdulrahmanamer/opt/anaconda3/envs/brother_rocks_workflow/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128 (\x80) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/abdulrahmanamer/opt/anaconda3/envs/brother_rocks_workflow/lib/python3.10/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 153 (\x99) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
